# %%
import streamlit as st
import pandas as pd
import numpy as np
import pickle
import six
import joblib
import sys
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
sys.modules['sklearn.externals.six'] = six
import joblib

# %%
model = joblib.load('model.sav')

# %%
def predict(model, input_df):
    predictions_df = predict_model(estimator=model, data=input_df)
    predictions = predictions_df['Label'][0]
    return predictions

# %%
from PIL import Image
def run():
    # Load and resize images
    image = Image.open('ChurnPHeading.png')
    image = image.resize((300, 100))
    image_meeting_room = Image.open('ChurnP.png')
    image_meeting_room = image_meeting_room.resize((300, 100))
    
    # Display images and sidebar options
    st.sidebar.image(image)
    add_selectbox = st.sidebar.selectbox(
        "How would you like to predict?",
        ("Online", "Batch", "About")
    )
    st.sidebar.info('This app is created to predict Churn rate')
    st.sidebar.image(image_meeting_room)
    st.title("Telecom Churn prediction")
    
    # Logic for the "Online" selection
    if add_selectbox == "Online":
        user_gender = st.selectbox("Select Gender:", ["Male", "Female"])
        user_phoneServices = st.selectbox("Select Phone Services:", ["Yes", "No"])
        user_InternetServices = st.selectbox("Use Internet Services:", ["Yes", "No"])
        if user_InternetServices=="Yes":
            user_KindOFservice = st.selectbox("Select Internet Services:", ["Fiber Optic", "DSL"])
        user_StreamingTV = st.selectbox("TV Streaming:", ["Yes", "No"])
        user_StreamingMovie = st.selectbox("Movie Streaming:", ["Yes", "No"])
        user_ContractType = st.selectbox("Contract Type:", ["Monthly", "Yearly","Two Year"])
        user_PaymentMethod = st.selectbox("Payment Method:", ["Bank Transfer", "Credit Card","Electric Check","Mailed Check"])
        user_tenureGroup = st.slider('Tenure Group', min_value =1, max_value =72 ,step=12, value=1)
        user_monthlyCharges=st.number_input("Enter a decimal number:", value=0.0, format="%.2f")
        user_TotalCharges=st.number_input('Total Charges',value=0.0,format="%.2f")
        output=""
        output1=""
        user_df_data = [[user_gender,user_phoneServices,user_InternetServices,user_KindOFservice,user_StreamingTV,user_StreamingMovie,user_ContractType,user_PaymentMethod,user_tenureGroup,user_monthlyCharges,user_TotalCharges]]
        input_data = {
        "Gender": [0 if user_gender == "Male" else 1],
        "PhoneService": [1 if user_phoneServices == "Yes" else 0],
        "InternetService_No": [1 if user_InternetServices == "Yes" else 0],
        "InternetService_DSL": [1 if user_KindOFservice == "DSL" else 0],
        "InternetService_Fiber optic": [1 if user_KindOFservice == "Fiber Optic" else 0],
        "StreamingTV": [1 if user_StreamingTV == "Yes" else 0],
        "StreamingMovies": [1 if user_StreamingMovie == "Yes" else 0],
        "Contract_Month-to-month": [1 if user_ContractType == "Monthly" else 0],
        "Contract_One year": [1 if user_ContractType == "Yearly" else 0],
        "Contract_Two year": [1 if user_ContractType == "Two Year" else 0],
        "PaymentMethod_Bank transfer (automatic)": [1 if user_PaymentMethod == "Bank Transfer" else 0],
        "PaymentMethod_Credit card (automatic)": [1 if user_PaymentMethod == "Credit Card" else 0],
        "PaymentMethod_Electronic check": [1 if user_PaymentMethod == "Electronic Check" else 0],
        "PaymentMethod_Mailed check": [1 if user_PaymentMethod == "Mailed Check" else 0],
        "tenure_group_1-12": [1 if 1 <= user_tenureGroup <= 12 else 0],
        "tenure_group_13-24": [1 if 13 <= user_tenureGroup <= 24 else 0],
        "tenure_group_25-36": [1 if 25 <= user_tenureGroup <= 36 else 0],
        "tenure_group_37-48": [1 if 37 <= user_tenureGroup <= 48 else 0],
        "tenure_group_49-60": [1 if 49 <= user_tenureGroup <= 60 else 0],
        "tenure_group_61-72": [1 if 61 <= user_tenureGroup <= 72 else 0],
        "MonthlyCharges": [user_monthlyCharges],
        "TotalCharges": [user_TotalCharges]
    }
        input_df = pd.DataFrame(input_data)
        if st.button("Predict"):
            output = predict(model=model, input_df=input_data)
            output_dict = {1 : 'Churn', 0 : 'Not Churn'}
            final_label = ""
            final_label = np.where(output == 1, 'Churn',np.where(output == 0,"Not Churn"))
            st.success(f'The Room will be {final_label}')
# Additional logic for "Batch" and "About" options can be added here

# Run the function

# %%
run()
# Out:
# 2024-11-08 21:11:42.875 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:42.878 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:42.971
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Harish jain\miniconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-11-08 21:11:42.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:42.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:42.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:42.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:42.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:42.991 Session state does not function when running a script without `streamlit run`
# 2024-11-08 21:11:42.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:42.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:42.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:42.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:42.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:42.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:42.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:42.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:42.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.000 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.000 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.003 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.004 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.005 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.010 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.010 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.013 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.016 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.019 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.020 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.029 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.037 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.037 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.039 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.039 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.041 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 21:11:43.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if add_selectbox == 'Batch':
    file_upload = st.file_uploader("Upload csv file for predictions", type=["csv"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 if add_selectbox == 'Batch':
#       2     file_upload = st.file_uploader("Upload csv file for predictions", type=["csv"])
#
# NameError: name 'add_selectbox' is not defined

# %%
import streamlit as st
import pandas as pd
import numpy as np
import pickle
import six
import joblib
import sys
from datetime import datetime
import warnings
from PIL import Image
warnings.filterwarnings('ignore')

# Load model (replace 'model.sav' with the actual model filename)
model = joblib.load('model.sav')

def predict(model, input_df):
    # Use model.predict to make predictions
    predictions = model.predict(input_df)
    return predictions[0]  # Assuming you want the first prediction for single input

def run():
    # Load and resize images
    image = Image.open('ChurnPHeading.png')
    image = image.resize((300, 100))
    image_meeting_room = Image.open('ChurnP.png')
    image_meeting_room = image_meeting_room.resize((300, 100))
    
    # Display images and sidebar options
    st.sidebar.image(image)
    add_selectbox = st.sidebar.selectbox(
        "How would you like to predict?",
        ("Online", "Batch", "About")
    )
    st.sidebar.info('This app is created to predict Churn rate')
    st.sidebar.image(image_meeting_room)
    st.title("Telecom Churn Prediction")
    
    # Logic for the "Online" selection
    if add_selectbox == "Online":
        user_gender = st.selectbox("Select Gender:", ["Male", "Female"])
        user_phoneServices = st.selectbox("Select Phone Services:", ["Yes", "No"])
        user_InternetServices = st.selectbox("Use Internet Services:", ["Yes", "No"])
        if user_InternetServices == "Yes":
            user_KindOFservice = st.selectbox("Select Internet Services:", ["Fiber Optic", "DSL"])
        else:
            user_KindOFservice=0
        user_StreamingTV = st.selectbox("TV Streaming:", ["Yes", "No"])
        user_StreamingMovie = st.selectbox("Movie Streaming:", ["Yes", "No"])
        user_ContractType = st.selectbox("Contract Type:", ["Monthly", "Yearly", "Two Year"])
        user_PaymentMethod = st.selectbox("Payment Method:", ["Bank Transfer", "Credit Card", "Electronic Check", "Mailed Check"])
        user_tenureGroup = st.slider('Tenure Group', min_value=1, max_value=72, step=12, value=1)
        user_monthlyCharges = st.number_input("Enter Monthly Charges:", value=0.0, format="%.2f")
        user_TotalCharges = st.number_input('Total Charges', value=0.0, format="%.2f")
        
        # Create input dictionary
        input_data = {
            "MonthlyCharges": [user_monthlyCharges],
            "TotalCharges": [user_TotalCharges],
            "Gender": [0 if user_gender == "Male" else 1],
            "PhoneService": [1 if user_phoneServices == "Yes" else 0],
            "InternetService_No": [1 if user_InternetServices == "Yes" else 0],
            "InternetService_Fiber optic": [1 if user_KindOFservice == "Fiber Optic" else 0],
            "InternetService_DSL": [2 if user_KindOFservice == "DSL" else 1],
            "StreamingTV": [1 if user_StreamingTV == "Yes" else 0],
            "StreamingMovies": [1 if user_StreamingMovie == "Yes" else 0],
            "Contract_Month-to-month": [1 if user_ContractType == "Monthly" else 0],
            "Contract_One year": [1 if user_ContractType == "Yearly" else 0],
            "Contract_Two year": [1 if user_ContractType == "Two Year" else 0],
            "PaymentMethod_Bank transfer (automatic)": [1 if user_PaymentMethod == "Bank Transfer" else 0],
            "PaymentMethod_Credit card (automatic)": [1 if user_PaymentMethod == "Credit Card" else 0],
            "PaymentMethod_Electronic check": [1 if user_PaymentMethod == "Electronic Check" else 0],
            "PaymentMethod_Mailed check": [1 if user_PaymentMethod == "Mailed Check" else 0],
            "tenure_group_1 - 12": [1 if 1 <= user_tenureGroup <= 12 else 0],
            "tenure_group_13 - 24": [1 if 13 <= user_tenureGroup <= 24 else 0],
            "tenure_group_25 - 36": [1 if 25 <= user_tenureGroup <= 36 else 0],
            "tenure_group_37 - 48": [1 if 37 <= user_tenureGroup <= 48 else 0],
            "tenure_group_49 - 60": [1 if 49 <= user_tenureGroup <= 60 else 0],
            "tenure_group_61 - 72": [1 if 61 <= user_tenureGroup <= 72 else 0]    
        }
        
        # Convert to DataFrame
        input_df = pd.DataFrame(input_data)
        
        # Predict when the button is clicked
        if st.button("Predict"):
            prediction = predict(model, input_df)
            prediction_label = "Churn" if prediction == 1 else "Not Churn"
            st.success(f'The prediction is: {prediction_label}')

    # if add_selectbox == 'Batch':
    #     file_upload = st.file_uploader("Upload csv file for predictions", type=["csv"])
    #     if file_upload is not None:
    #         data = pd.read_csv(file_upload)
    #         predictions = model.predict(data)
    #         st.write(predictions)
    
    if add_selectbox == 'Batch':
        file_upload = st.file_uploader("Upload csv file for predictions", type=["csv"])
        if file_upload is not None:
        # Load data
            data = pd.read_csv(file_upload)
            
            # Remove unwanted columns like 'Unnamed: 0'
            data = data.drop(columns=['Unnamed: 0'], errors='ignore')
            
            # Ensure the columns match the trained model (replace 'Feature1', etc., with actual names)
            expected_columns = ['MonthlyCharges', 'TotalCharges', 'Gender', 'PhoneService','InternetService_No', 'InternetService_Fiber optic', 'InternetService_DSL', 'StreamingTV','StreamingMovies', 'Contract_Month-to-month', 'Contract_One year', 'Contract_Two year','PaymentMethod_Bank transfer (automatic)', 'PaymentMethod_Credit card (automatic)', 'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check','tenure_group_1 - 12', 'tenure_group_13 - 24', 'tenure_group_25 - 36', 'tenure_group_37 - 48', 'tenure_group_49 - 60', 'tenure_group_61 - 72']
            data = data[expected_columns]
            output = data[['Customer_id']].copy()
            output['Churn'] = predictions
            # Make predictions
            predictions = model.predict(data)
            # st.write(predictions)
            
            csv = output.to_csv(index=False)
            st.download_button(
            label="Download predictions as CSV",
            data=csv,
            file_name='predictions.csv',
            mime='text/csv'
            )

    if add_selectbox == 'About':
        st.subheader("Built with Streamlit and Pycaret")
        st.subheader("Nishtha Jain")
        # st.subheader("https://www.linkedin.com/in/hunaidkhan/")
        # st.button("Re-run")

    
# Run the function
run()
# Out:
# 2024-11-09 11:32:49.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.216 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 11:32:49.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
